# %%
from analysis import *

# %%
path = f'path/to/data/result_20210331_084932'
art = AnalyseRos2Test(path)
art.data

# %%
path = f'path/to/data/result_20210331_084932'
draw_figure(path, True)
# Out:
# PosixPath('/Users/knishikawa/Documents/Lab/ros2_test/analysis/results/ros2_test_result_20210331084932.pdf')
